# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/Users/mingikim/tutorial-env/bin/input/lotto_test.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       date  PB1  PB2  PB3  PB4  PB5  Powerball  Unnamed: 8
# 0         874  2019.8.31    1   15   19   23   28         42          32
# 1         873  2019.8.24    3    5   12   13   33         39          38
# 2         872  2019.8.17    2    4   30   32   33         43          29
# 3         871  2019.8.10    2    6   12   26   30         34          38
# 4         870   2019.8.3   21   25   30   32   40         42          31

# %%
list=["C123", "2020/09"]
list
# Out:
# ['C123', '2020/09']

# %%
a = list[0]
b = list[1]
if a in list:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
temp=["2019.8"]
temp
# Out:
# ['2019.8']

# %%
cu = df[df.PB1.str.contains('1')]
cu
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1a88c5065f44> in <module>
# ----> 1 cu = df[df.PB1.str.contains('1')]
#       2 cu
#
# ~/tutorial-env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5174             or name in self._accessors
#    5175         ):
# -> 5176             return object.__getattribute__(self, name)
#    5177         else:
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/tutorial-env/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
# ...

# %%
yes
# Out:
#     Unnamed: 0       date  PB1  PB2  PB3  PB4  PB5  Powerball  Unnamed: 8
# 0          874  2019.8.31    1   15   19   23   28         42          32
# 1          873  2019.8.24    3    5   12   13   33         39          38
# 2          872  2019.8.17    2    4   30   32   33         43          29
# 3          871  2019.8.10    2    6   12   26   30         34          38
# 4          870   2019.8.3   21   25   30   32   40         42          31
# 5          869  2019.7.27    2    6   20   27   37         39           4
# 6          868  2019.7.20   12   17   28   41   43         44          25
# 7          867  2019.7.13   14   17   19   22   24         40          41
# 8          866   2019.7.6    9   15   29   34   37         39          12
# 9          865  2019.6.29    3   15   22   32   33         45           2
# 10         864  2019.6.22    3    7   10   13   25         36          32
# 11         863  2019.6.15   16   21   28   35   39         43          12
# ...
